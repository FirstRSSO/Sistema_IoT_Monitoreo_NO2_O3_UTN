# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Ruta del archivo del modelo
path = "modelo_red"
# Cargar el modelo de Keras
model = tf.keras.models.load_model(path + ".h5")

converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Guardar el modelo convertido en un archivo .tflite
with open(path + '.tflite', 'wb') as f:
    f.write(tflite_model)
print("\r\nTensorFlow Keras H5 model converted to a TensorFlow Lite model!\r\n")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: C:\Users\Nelvita\AppData\Local\Temp\tmpupwuy_ul\assets
# INFO:tensorflow:Assets written to: C:\Users\Nelvita\AppData\Local\Temp\tmpupwuy_ul\assets
# Saved artifact at 'C:\Users\Nelvita\AppData\Local\Temp\tmpupwuy_ul'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 4), dtype=tf.float32, name='input_layer_2')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   1993710643408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1993986253712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1993986253328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1993986252176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1993986247376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1993986254288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#
# TensorFlow Keras H5 model converted to a TensorFlow Lite model!
